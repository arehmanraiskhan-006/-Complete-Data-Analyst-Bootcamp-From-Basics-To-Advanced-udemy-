# %% [markdown]
# #### Data Types

# %%
#Data types are a classification of data that tells the compiler or interpreter how the programmer intends to use the data.
#They determine the type of operation that can be performed on the data, the values that the data can take, and the amount of memory needed to store the data.

#Different data types, such as integer and floating point, require different amounts of memory. 
#For example, you may have int (8 bit), float (16 bits), and so on. Each data type stores information in a specific way.

# %% [markdown]
# ##### Integer Data Type Example

# %%
age = 35
type(age)
# Out:
# int

# %% [markdown]
# ##### Floating Point Data Type Example

# %%
height = 5.9
print(height)
type(height)
# Out:
# 5.9
# float

# %% [markdown]
# ##### String Data Type Example

# %%
name = "Rais"
print(name)
print(type(name))
# Out:
# Rais
# <class 'str'>

# %% [markdown]
# ##### Boolean Data Type Example

# %%
is_true = True
type(is_true)
# Out:
# bool

# %%
a = 10
b = 10
a == b
type(a == b)
# Out:
# bool

# %% [markdown]
# ##### Common Errors with Data Types

# %%
result = "hello"
result = result + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 result = "hello"
# ----> 2 result = result + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
result = "hello" + str(5)
print(result)
# Out:
# hello5
